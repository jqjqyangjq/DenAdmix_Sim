# %%
# # This script replicate demographic models for Neanderthals and Denisovans from previous studies .
a = []
# add parameters inferred for Denisova3, from Prufer 2017, high-coverage Vindija Neanderthal paper
a.append("ms 2 1 -t 3215.941 -r 497.848889692575 30000000 -en 0.0224 1 0.6683 -en 0.0373 1 1.2633 -en 0.0552 1 1.5349 -en 0.0769 1 1.2425 -en 0.1031 1 0.8649 -en 0.1349 1 0.7299 -en 0.1733 1 0.7947 -en 0.2197 1 0.9664 -en 0.2758 1 1.1379 -en 0.3437 1 1.2766 -en 0.4258 1 1.4448 -en 0.5252 1 1.6290 -en 0.6452 1 1.7332 -en 0.7905 1 1.7182 -en 0.9661 1 1.6411 -en 1.1786 1 1.6021 -en 1.4354 1 1.7259 -en 1.7461 1 2.1842 -en 2.1218 1 3.1602 -en 2.5762 1 4.6545 -en 3.1258 1 6.3211 -en 3.7903 1 7.6928 -en 4.5940 1 8.5163 -en 5.5660 1 8.6435 -en 6.7415 1 7.8947 -en 8.1631 1 5.5635 -en 11.9614 1 25.2126 ")

# add parameters inferred for Vindija 33.19, from Mafessoni 2020, high-coverage chagyrskaya Neanderthal paper
a.append("ms 2 1 -t 13041.14772872183 -r 3048.50564922064 249230605 -en 0.0436 1 0.4496 -en 0.0724 1 1.1386 -en 0.1073 1 1.6976 -en 0.1494 1 2.1414 -en 0.2004 1 2.5273 -en 0.2620 1 2.7677 -en 0.3365 1 2.8236 -en 0.4266 1 2.7121 -en 0.5355 1 2.6260 -en 0.6671 1 2.6174 -en 0.8264 1 2.5544 -en 1.0189 1 2.4373 -en 1.2516 1 2.4051 -en 1.5331 1 2.5286 -en 1.8733 1 2.8193 -en 2.2848 1 3.2856 -en 2.7822 1 4.1041 -en 3.3837 1 5.6754 -en 4.1109 1 8.3609 -en 4.9902 1 11.8388 -en 6.0533 1 14.8836 -en 7.3388 1 16.7310 -en 8.8930 1 17.6350 -en 10.7722 1 17.6137 -en 13.0443 1 16.1529 -en 15.7915 1 12.0577 -en 23.1293 1 44.8768")

# add parameters inferred for Chagyrskaya 8, from Mafessoni 2020, high-coverage chagyrskaya Neanderthal paper
a.append("ms 2 1 -t 2748.38749554598 -r 653.111605863336 249230605 -en 0.1728 1 2.0395 -en 0.2880 1 4.2353 -en 0.4282 1 6.3325 -en 0.5986 1 8.8150 -en 0.8058 1 11.6664 -en 1.0577 1 13.8983 -en 1.3640 1 13.8425 -en 1.7363 1 13.0453 -en 2.1891 1 12.8561 -en 2.7396 1 12.8571 -en 3.4090 1 12.6969 -en 4.2228 1 12.5652 -en 5.2123 1 12.6974 -en 6.4153 1 13.1013 -en 7.8781 1 13.7268 -en 9.6566 1 14.8088 -en 11.8190 1 17.2506 -en 14.4482 1 23.0490 -en 17.6449 1 35.2529 -en 21.5317 1 54.9353 -en 26.2574 1 75.7921 -en 32.0032 1 87.9151 -en 38.9893 1 89.7266 -en 47.4833 1 86.4670 -en 57.8109 1 79.3633 -en 70.3677 1 57.3675 -en 104.1979 1 206.3010")

# add parameters inferred for Altai Neanderthal, from Mafessoni 2020, high-coverage chagyrskaya Neanderthal paper
a.append("scrm 2 1 -t 5484.46414949352 -r 1273.698712986202 249230605 -en 0.0997 1 1.3763 -en 0.1659 1 1.9359 -en 0.2462 1 2.8299 -en 0.3434 1 3.7586 -en 0.4613 1 5.0165 -en 0.6041 1 6.2030 -en 0.7773 1 6.9742 -en 0.9871 1 7.0692 -en 1.2415 1 6.7771 -en 1.5497 1 6.4688 -en 1.9233 1 6.2562 -en 2.3760 1 6.2782 -en 2.9247 1 6.5188 -en 3.5898 1 6.8857 -en 4.3958 1 7.4881 -en 5.3727 1 8.9953 -en 6.5566 1 12.6641 -en 7.9916 1 19.4238 -en 9.7306 1 28.1659 -en 11.8384 1 35.6656 -en 14.3929 1 39.7922 -en 17.4889 1 40.9909 -en 21.2412 1 40.5491 -en 25.7889 1 39.3030 -en 31.3005 1 37.0012 -en 37.9805 1 30.9487 -en 55.8887 1 101.6739")

# %%
N_Archaic = []
def weighted_harmonic_mean(a, b):
    numerator = sum(b)
    denominator = sum(bi / ai for ai, bi in zip(a, b))
    return numerator / denominator

for archaic, param in zip(['Denisova3','Vindija','Chagyrskaya','Altai'], a):
    param_ = param.strip().split()
#    print(f"Archaic: {archaic}, Mutation Rate: {muterate}")
    intervals = int(((len(param_)) - 8) / 4)
    #print(intervals)
    N0 = float(param_[4]) / (4 * 1.4e-8 * float(param_[7]))
    Ne = N0
    Ns = []
    Ts = []
    0.0224 * 4 * N0 * 29
    Years = 0
    for i in range(0,intervals):
        if Years < 300000:
            _, t, _, ne = param_[(8 + i * 4): (8 + i * 4 + 4)]
            t = float(t)
            ne = float(ne)
            Years += t * 4 * N0 * 29
            Ns.append(Ne)
            Ts.append(t)
            Ne = N0 * float(ne)
    whm = weighted_harmonic_mean(Ns, Ts)
    print("Weighted Harmonic Mean:", whm)
    N_Archaic.append(whm)
# Out:
# Weighted Harmonic Mean: 1825.6671984045693
# Weighted Harmonic Mean: 2000.360533575577
# Weighted Harmonic Mean: 1865.231138043393
# Weighted Harmonic Mean: 1964.2321550084062

# %%
print("pop size used for each Denisovan lineage:", N_Archaic[0])
print("pop size used for each Neanderthal lineage:", (N_Archaic[1] + N_Archaic[2] + N_Archaic[3]) / 3)
# Out:
# pop size used for each Denisovan lineage: 1825.6671984045693
# pop size used for each Neanderthal lineage: 1943.2746088757922
